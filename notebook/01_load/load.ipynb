# %% [markdown]
# Load Dataset for Quality and type assessment before analysis

# %%
# import Necessary Libraries for loading dat

# %%
from src.load import loader_dataFrame as loader

Data = loader("../data/raw/world-gdp/world_gdp.csv")

# %%
# Check data First ten rows
Data.head(10)
# Out:
#                   Country Name Country Code  ...          2022 Unnamed: 67
# 0                        Aruba          ABW  ...           NaN         NaN
# 1  Africa Eastern and Southern          AFE  ...  1.169484e+12         NaN
# 2                  Afghanistan          AFG  ...           NaN         NaN
# 3   Africa Western and Central          AFW  ...  8.778633e+11         NaN
# 4                       Angola          AGO  ...  1.067136e+11         NaN
# 5                      Albania          ALB  ...  1.888210e+10         NaN
# 6                      Andorra          AND  ...  3.352033e+09         NaN
# 7                   Arab World          ARB  ...  3.557557e+12         NaN
# 8         United Arab Emirates          ARE  ...  5.075349e+11         NaN
# 9                    Argentina          ARG  ...  6.327703e+11         NaN
#
# [10 rows x 68 columns]

# %%
# Check data Last ten rows
Data.tail(10)
# Out:
#               Country Name Country Code  ...          2022 Unnamed: 67
# 256  Virgin Islands (U.S.)          VIR  ...           NaN         NaN
# 257               Viet Nam          VNM  ...  4.088024e+11         NaN
# 258                Vanuatu          VUT  ...  9.835829e+08         NaN
# 259                  World          WLD  ...  1.005620e+14         NaN
# 260                  Samoa          WSM  ...  8.324216e+08         NaN
# 261                 Kosovo          XKX  ...  9.429156e+09         NaN
# 262            Yemen, Rep.          YEM  ...           NaN         NaN
# 263           South Africa          ZAF  ...  4.058697e+11         NaN
# 264                 Zambia          ZMB  ...  2.978445e+10         NaN
# 265               Zimbabwe          ZWE  ...  2.067806e+10         NaN
#
# [10 rows x 68 columns]

# %%
# Check data infomation
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            132 non-null    float64
#  5   1961            134 non-null    float64
#  6   1962            136 non-null    float64
#  7   1963            136 non-null    float64
#  8   1964            136 non-null    float64
#  9   1965            147 non-null    float64
#  10  1966            150 non-null    float64
#  11  1967            153 non-null    float64
#  12  1968            158 non-null    float64
#  13  1969            158 non-null    float64
#  14  1970            167 non-null    float64
#  15  1971            170 non-null    float64
#  16  1972            170 non-null    float64
# ...

# %%
# Check Descriptive Statistics of the data
Data.describe()
# Out:
#                1960          1961  ...          2022  Unnamed: 67
# count  1.320000e+02  1.340000e+02  ...  2.330000e+02          0.0
# mean   7.127083e+10  7.274846e+10  ...  3.599794e+12          NaN
# std    2.135947e+11  2.223876e+11  ...  1.147950e+13          NaN
# min    1.201203e+07  1.159202e+07  ...  6.034939e+07          NaN
# 25%    5.288385e+08  5.361919e+08  ...  1.567158e+10          NaN
# 50%    3.040214e+09  2.965945e+09  ...  8.227481e+10          NaN
# 75%    3.103045e+10  3.128542e+10  ...  9.911146e+11          NaN
# max    1.384857e+12  1.449221e+12  ...  1.005620e+14          NaN
#
# [8 rows x 64 columns]

# %%
# View columns for data consistency
Data.columns.unique()
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %% [markdown]
# **Load Dataset of oil producing country**

# %%
oil_states = loader("../data/raw/world-gdp/oil_producing_state.csv")

# %%
oil_states.head(10)
oil_states.describe(include="all")
oil_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   States      106 non-null    object
#  1   Unnamed: 1  0 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 1.8+ KB

# %%
oil_states.columns.unique()
# Out:
# Index(['States', 'Unnamed: 1'], dtype='object')
